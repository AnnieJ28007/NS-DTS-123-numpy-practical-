# %%
import numpy as np
numbers = [45,67,89,52,73,91,38,60]
print (numbers)
# Out:
# [45, 67, 89, 52, 73, 91, 38, 60]

# %%
#Q1
import numpy as np
numbers= np.array([45,67,89,52,73,91,38,60])
print(numbers.size)
# Out:
# 8

# %%
#Q2
print(np.max(numbers))
# Out:
# 91

# %%
#Q3
print(np.min(numbers))
# Out:
# 38

# %%
#Q4
print(np.mean(numbers))
# Out:
# 64.375

# %%
#Q5
print(np.sum(numbers))
# Out:
# 515

# %%
#Q6
Scores = np.array ([45,67,89,52,73,91,38,60])
Passed = Scores [Scores >=50]
print(Passed)
# Out:
# [67 89 52 73 91 60]

# %%
#Q7
print(np.sum(Scores >=50))
# Out:
# 6
